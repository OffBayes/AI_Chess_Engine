# %%
import chess

# %%
dir(chess)
# Out:
# ['A1',
#  'A2',
#  'A3',
#  'A4',
#  'A5',
#  'A6',
#  'A7',
#  'A8',
#  'AmbiguousMoveError',
#  'B1',
#  'B2',
#  'B3',
#  'B4',
#  'B5',
#  'B6',
#  'B7',
#  'B8',
#  'BB_A1',
#  'BB_A2',
#  'BB_A3',
#  'BB_A4',
#  'BB_A5',
#  'BB_A6',
#  'BB_A7',
#  'BB_A8',
#  'BB_ALL',
#  'BB_B1',
#  'BB_B2',
#  'BB_B3',
#  'BB_B4',
#  'BB_B5',
#  'BB_B6',
#  'BB_B7',
#  'BB_B8',
#  'BB_BACKRANKS',
#  'BB_C1',
#  'BB_C2',
#  'BB_C3',
#  'BB_C4',
#  'BB_C5',
#  'BB_C6',
#  'BB_C7',
#  'BB_C8',
#  'BB_CENTER',
#  'BB_CORNERS',
#  'BB_D1',
#  'BB_D2',
#  'BB_D3',
#  'BB_D4',
#  'BB_D5',
#  'BB_D6',
#  'BB_D7',
#  'BB_D8',
#  'BB_DARK_SQUARES',
#  'BB_DIAG_ATTACKS',
#  'BB_DIAG_MASKS',
#  'BB_E1',
#  'BB_E2',
#  'BB_E3',
#  'BB_E4',
#  'BB_E5',
#  'BB_E6',
#  'BB_E7',
#  'BB_E8',
#  'BB_EMPTY',
#  'BB_F1',
#  'BB_F2',
#  'BB_F3',
#  'BB_F4',
#  'BB_F5',
#  'BB_F6',
#  'BB_F7',
#  'BB_F8',
#  'BB_FILES',
#  'BB_FILE_A',
#  'BB_FILE_ATTACKS',
#  'BB_FILE_B',
#  'BB_FILE_C',
#  'BB_FILE_D',
# ...

# %%
board = chess.Board()
board
# Out:
# Board('rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w KQkq - 0 1')

# %%
board.legal_moves
# Out:
# <LegalMoveGenerator at 0x26d70853920 (Nh3, Nf3, Nc3, Na3, h3, g3, f3, e3, d3, c3, b3, a3, h4, g4, f4, e4, d4, c4, b4, a4)>

# %%
board.push_san('d4')
# Out:
# Move.from_uci('d2d4')

# %%
board
# Out:
# Board('rnbqkbnr/pppppppp/8/8/3P4/8/PPP1PPPP/RNBQKBNR b KQkq - 0 1')

# %%
board.legal_moves
# Out:
# <LegalMoveGenerator at 0x26d73299670 (Nh6, Nf6, Nc6, Na6, h6, g6, f6, e6, d6, c6, b6, a6, h5, g5, f5, e5, d5, c5, b5, a5)>

# %%
 board.is_check()
# Out:
# False

# %%
board.is_checkmate
# Out:
# <bound method Board.is_checkmate of Board('rnbqkbnr/pppppppp/8/8/3P4/8/PPP1PPPP/RNBQKBNR b KQkq - 0 1')>

# %%
board.copy()
# Out:
# Board('rnbqkbnr/pppppppp/8/8/3P4/8/PPP1PPPP/RNBQKBNR b KQkq - 0 1')

# %%
board2 = board.copy()

# %%
board2.push_san('d5')
board2
# Out:
# Board('rnbqkbnr/ppp1pppp/8/3p4/3P4/8/PPP1PPPP/RNBQKBNR w KQkq - 0 2')

# %%
board
# Out:
# Board('rnbqkbnr/pppppppp/8/8/3P4/8/PPP1PPPP/RNBQKBNR b KQkq - 0 1')
